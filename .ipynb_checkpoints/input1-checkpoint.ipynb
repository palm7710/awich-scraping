# %%
import pandas as pd
from janome.tokenizer import Tokenizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# CSVファイルを読み込み
file_path = 'Awich_songs_df.csv'
# 正しいエンコーディングを指定
df = pd.read_csv(file_path, encoding='cp932')
print(df.head())
# Out:
#    Unnamed: 0                         song_name  \
# 0           0                             Awake
# 1           1                             Ashes
# 2           2                           Arigato
# 3           3  ALI BABA REMIX feat. MFS & ralph
# 4           4                      If She Cries
#
#                                               lyrics release_date impression
# 0  Pandemic Plandemic地球よ　are you ready？消えてくmoney　...    2020/8/21       情報なし
# 1  First I heistedBut I called your mom backCause...     2017/8/8       情報なし
# 2  I'll cry you a river海へと渡るこの涙Will heal my soul ...    2020/1/11       情報なし
# 3  Gang してく GangBag してく BagAli BabaAli BabaGang し...   2023/10/25       情報なし
# 4  Did she pick you up when you're broken？Did she...   2018/10/10       情報なし

# %%
senno = df.loc[29,'lyrics']

# %%
# トークナイザーの初期化
t = Tokenizer()
tokens = t.tokenize(senno)

word_list = []
for token in tokens:
    word = token.surface
    partOfSpeech = token.part_of_speech.split(',')[0]
    partOfSpeech2 = token.part_of_speech.split(',')[1]

    if partOfSpeech in ['名詞', '動詞', '形容詞', '形容動詞']:
        if partOfSpeech != "記号":
            if partOfSpeech2 not in ["非自立", "代名詞", "数"]:
                word_list.append(word)

words = " ".join(word_list)

# %%
# 結果をファイルに書き込む
output_file = 'output.txt'
with open(output_file, 'w', encoding='utf-8') as f:
    f.write(words)

print(f"Results written to {output_file}")
# Out:
# Results written to output.txt

# %%
words = " ".join(word_list)

# 結果を標準出力に出力
print(words.encode('utf-8').decode('utf-8'))
# Out:
# 下界 忍ぶ 体 菩薩 Neo babylonia 街 歩く 丸く 背 曲げ 足取り 深く 毒 持つ 蛇 好む 孔雀 Street democracyPussy Power Politics スキャンダル 種まき 分割 統治 指 さし 愚か 凡人 Stigma 中心 勢力 解体 Not nice not nice not a ting nice 誓約 書 サイン する ボールペンナイフビート 殺め 金 生む MidwifeNot nice not a motherfucking ting nice 子 末路 イ ない イ ない 不感 マグロ 失望 借金 効く 薬 Don ' t open yo fuckin mouth 運命 名 情報 戦 知ら 受け取る 処方箋 セックス スポーツ スクリーン 目 眩む 愚民 操る ルー ティーン 咥 え ルアー 針 ゴクリ 飲み込み 後頭部 圧迫 失脚 Now what you wanna do バカ 飽き 味 し ガム 派手 ビジュアル 客 並ん 引っ張っ 押し 一般 世間体 目 見え ヒモ 見える 究極 面白けりゃ いい 感情 移入 洗脳 する ゲームサテンシャツ 着 ペテン師 踊る マウンティング とる マーケティングビジネスバズ スキャンダルアタ 札束 頭 ひっぱたく 良い 悪い 毒 使い方 殺し 数 やりゃ 独裁 者 化す 不幸 群がる 癖 自慢 つまみ 酒 未曾有 恐怖 操ら れ 欲し がる 情報 源 透明 命 弄ば れ 菩薩 輸血 死ぬ 怪我 ブルー シート 奥 いる ガキ 死に ざ 趣味 メディア 欲 底なし 勘ぐる 踊れ 日本 メイドインアメリカ 形 変え 快楽 快感 連続 バカ バカ カミ 数字 書か れ カミ 信じ 御多分 もれ カミ 力 おくっ 日常 アスファルト よろしく 敷き詰め られ ルール 普通 言葉 思考 回路 巧み 絡みつき 根 はら れ 運 尽き 想像 力 影響 し 行動 パターン 設定 プログラミング 教育 ウィーアーザロボット クラフト ワーク 出来 違い 仕分ける ベルトコンベアー 揺り 籠 墓場 そびえ立つ 三角 立場 力 競争 勝敗 商売 なっ 戦争 行か なりゃ ー 発 ぶち込む 核 爆弾 人類 運命 共同 体 今 地球 泣い ナイトメア 不安 材料 絶え 機会 契約 書 判子 指定 口座 振り込み し いただけれ 毎度 バカ 歌詞 マイ 歌 ネット 登録 > アーティスト マイ 歌 ネット 登録 >

# %%
stop_words = ['し', 'さ', 'れ', 'ない']

fpath = '/System/Library/Fonts/ヒラギノ角ゴシック W5.ttc'  # フォントファイルのパスを確認

# %%
wordcloud = WordCloud(
    font_path=fpath,
    width=900, height=600,
    background_color="white",
    stopwords=set(stop_words),
    max_font_size=40,  # フォントサイズを適切に設定
    collocations=False
).generate(words)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-5028cb0d1d5a> in <module>
# ----> 1 wordcloud = WordCloud(
#       2     font_path=fpath,
#       3     width=900, height=600,
#       4     background_color="white",
#       5     stopwords=set(stop_words),
#
# /Applications/anaconda3/lib/python3.8/site-packages/wordcloud/wordcloud.py in generate(self, text)
#     640         self._check_generated()
#     641         if self.mask is not None:
# --> 642             width = self.mask.shape[1]
#     643             height = self.mask.shape[0]
#     644         else:
#
# /Applications/anaconda3/lib/python3.8/site-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     622
#     623         Alias to generate_from_text.
# --> 624
#     625         Calls process_text and generate_from_frequencies.
#     626
#
# /Applications/anaconda3/lib/python3.8/site-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     509                 # if we didn't find a place, make font smaller
#     510                 # but first try to rotate!
# --> 511                 if not tried_other_orientation and self.prefer_horizontal < 1:
#     512                     orientation = (Image.ROTATE_90 if orientation is None else
#     513                                    Image.ROTATE_90)
#
# /Applications/anaconda3/lib/python3.8/site-packages/PIL/ImageDraw.py in textbbox(self, xy, text, font, anchor, spacing, align, direction, features, language, stroke_width, embedded_color)
#     649             font = self.getfont()
#     650         if not isinstance(font, ImageFont.FreeTypeFont):
# --> 651             raise ValueError("Only supported for TrueType fonts")
#     652         mode = "RGBA" if embedded_color else self.fontmode
#     653         bbox = font.getbbox(
#
# ValueError: Only supported for TrueType fonts

# %%
plt.figure(figsize=(15,12))
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.savefig("senno.png")
plit.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-cc30c7d7cc1e> in <module>
#       1 plt.figure(figsize=(15,12))
# ----> 2 plt.imshow(wordcloud,interpolation="bilinear")
#       3 plt.axis("off")
#       4 plt.savefig("senno.png")
#       5 plit.show()
#
# NameError: name 'wordcloud' is not defined

# %%
import pandas as pd
from janome.tokenizer import Tokenizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import ImageFont, ImageDraw, Image

# CSVファイルを読み込み
file_path = 'Awich_songs_df.csv'
df = pd.read_csv(file_path, encoding='cp932')
print(df.head())

# 'lyrics'列の15行目を抽出
senno = df.loc[15, 'lyrics']

# トークナイザーの初期化
t = Tokenizer()
tokens = t.tokenize(senno)

word_list = []
for token in tokens:
    word = token.surface
    partOfSpeech = token.part_of_speech.split(',')[0]
    partOfSpeech2 = token.part_of_speech.split(',')[1]

    if partOfSpeech in ['名詞', '動詞', '形容詞', '形容動詞']:
        if partOfSpeech != "記号":
            if partOfSpeech2 not in ["非自立", "代名詞", "数"]:
                word_list.append(word)

words = " ".join(word_list)
print(words)

# 結果をファイルに書き込む
output_file = 'output.txt'
with open(output_file, 'w', encoding='utf-8') as f:
    f.write(words)

# ファイルを読み込む
with open(output_file, 'r', encoding='utf-8') as f:
    text = f.read()

# WordCloudの生成
stop_words = ['し', 'さ', 'れ', 'ない']
fpath = '/System/Library/Fonts/ヒラギノ角ゴシック W5.ttc'  # 適切なフォントパスを指定

try:
    wordcloud = WordCloud(
        font_path=fpath,
        width=900, height=600,
        background_color="white",
        stopwords=set(stop_words),
        max_font_size=40,
        collocations=False
    ).generate(text)

    plt.figure(figsize=(15, 12))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt